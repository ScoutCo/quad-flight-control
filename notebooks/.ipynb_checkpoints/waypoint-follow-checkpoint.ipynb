# %%
import sys

from mcap.reader import make_reader

# %%
LOGROOT = "/home/mschoder/logs/"

LOGFILE = "2025-10-07_23-26-38-utc__A01-A001__598a4fea-ef59-41dd-9257-0bf9c3d2a3e3.mcap"
# LOGFILE = "2025-10-07_22-55-01-utc__A01-A001__3af6a9c3-8a79-46ac-b018-1e470ca50d77.mcap"
# LOGFILE = "2025-09-17_01-39-51-utc__A01-A001__0f1d4d53-9ff7-4c38-b312-bb04e1f87f2d.mcap"

# %%
# List of topic we care about
topics = [
    # "/scout/autopilot/telemetry/odometry",
    # "/scout/autopilot/action/mux/autonomy/request",
    # "/scout/vla/plan"
]

# %%
with open(LOGROOT + LOGFILE, "rb") as f:
    reader = make_reader(f)
    for schema, channel, message in reader.iter_messages(topics=topics):
        print(f"{channel.topic} ({schema.name}): {message.data}")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
